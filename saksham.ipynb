# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/train.csv")
movie = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/movies.csv")
test = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/test.csv")

# %%
len(movie['movieid'].unique())

# %%
len(train['movieid'].unique())
# movie['genre'].loc[movie['movieid']=='escape_the_terminator_tyler_durden_astonish'].value_counts()

# %%
# movie.query('movieid == "rick_blaine_epic_mr._miyagi"')

# %%
len(train['movieid'][train['movieid'].duplicated()].unique())

# %%
train

# %%
test

# %%
len(test['movieid'].unique())

# %%
train_df = pd.merge(train,movie,on='movieid')

# %%
train.info()

# %%
test.info()

# %%
train_df

# %%
c = train_df.columns

# %%
c

# %%
train['movieid'][train['movieid'].duplicated()].value_counts()

# %%
train

# %%
test

# %%
movie

# %%
train_cl = train_df.drop(['releaseDateTheaters','releaseDateStreaming','runtimeMinutes','boxOffice','distributor','soundType','originalLanguage'],axis=1)

# %%
train_cl = train_df.drop(['releaseDateTheaters','releaseDateStreaming','runtimeMinutes','boxOffice','distributor','soundType','originalLanguage','reviewerName'],axis=1)

# %%
len(train_cl['director'].value_counts())

# %%
train_cl.info()

# %%
# train_cl[train_cl['isFrequentReviewer']==True]

# %%
duplicated_movie = list(movie['movieid'][movie['movieid'].duplicated()])

# %%
leng = len(duplicated_movie)

# %%
leng

# %%
si = int(leng/6)

# %%
si

# %%
duplicated_movie1 = duplicated_movie[:si]
duplicated_movie2 = duplicated_movie[si:2*si]
duplicated_movie3 = duplicated_movie[2*si:3*si]
duplicated_movie4 = duplicated_movie[3*si:4*si]
duplicated_movie5 = duplicated_movie[4*si:5*si]
duplicated_movie6 = duplicated_movie[5*si:6*si]

# %%
len(duplicated_movie3)

# %%
movie.head()

# %%
movie_t = movie.drop(['releaseDateTheaters','releaseDateStreaming','runtimeMinutes','boxOffice','distributor','soundType','originalLanguage'],axis=1)

# %%
movie_col = movie_t.columns

# %%
len(movie_col)

# %%
# movie_t[movie_t['movieid']=='heroic_legendary_ellis_redding'].index.tolist()
movie_t.iloc[101292]

# %%
for i in duplicated_movie1:   #len(duplicated_movie)
#     if ep==0:
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==i])
    li = movie_t[movie_t['movieid']==i].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
for i in duplicated_movie2:   #len(duplicated_movie)
#     if ep==0:
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==i])
    li = movie_t[movie_t['movieid']==i].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
for i in range(len(duplicated_movie3)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicated_movie3[i]])
    li = movie_t[movie_t['movieid']==duplicated_movie3[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
for i in range(len(duplicated_movie4)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicated_movie4[i]])
    li = movie_t[movie_t['movieid']==duplicated_movie4[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
for i in range(len(duplicated_movie5)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicated_movie5[i]])
    li = movie_t[movie_t['movieid']==duplicated_movie5[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
 for i in range(len(duplicated_movie6)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicated_movie6[i]])
    li = movie_t[movie_t['movieid']==duplicated_movie6[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
movie_t

# %%
len(movie_t['movieid'].unique())

# %%
duplicate7 = list(movie_t['movieid'][movie_t['movieid'].duplicated()])

# %%
len(duplicate7)

# %%
 for i in range(len(duplicate7)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicate7[i]])
    li = movie_t[movie_t['movieid']==duplicate7[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
movie_t

# %%
duplicate8 = list(movie_t['movieid'][movie_t['movieid'].duplicated()])

# %%
len(duplicate8)

# %%
 for i in range(len(duplicate8)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicate8[i]])
    li = movie_t[movie_t['movieid']==duplicate8[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
duplicate9 = list(movie_t['movieid'][movie_t['movieid'].duplicated()])

# %%
len(duplicate9)

# %%
 for i in range(len(duplicate9)):   #len(duplicated_movie)
#     if ep==0:
#     print(i)
    count=[]
    c=0
    genre={}
    l = len(movie_t[movie_t['movieid']==duplicate9[i]])
    li = movie_t[movie_t['movieid']==duplicate9[i]].index.tolist()
#     print(l,li)
    for k in range(len(li)):
        try:
#             print(li[k],i)
            m = movie_t.iloc[li[k]]
            c=0
            min_count=[]
    #         print(m)
            if pd.isna(m[5]):
                pass
            else:
                g = list(m[5].split(", "))
    #             print(g)
                for f in range(len(g)):
                    if g[f] not in genre.keys():
                        genre[g[f]]=1
                    else:
                        genre[g[f]]+=1    
            for j in range(len(movie_col)):
                if pd.isna(m[j]):
                    c+=1
            count.append(c)
        except:
            min_count=[]
            count.append(10)
#     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
    for s in range(len(count)):
        if count[s]==min(count):
            min_count.append((s,li[s]))
#     print(li)
    v = list(genre.values())
    k = list(genre.keys())
    if len(v)>0:
        ge = k[v.index(max(v))]
#             print(count[s])
#     print(count)        
#     print(min_count[0][1])
        if len(min_count)==1:
            li.remove(min_count[0][1])
        else:
            b=0
            for t in range(len(min_count)):
                m = movie_t.iloc[min_count[t][1]]
#                 print(m)
                if pd.isna(m[5]):
                    pass
                else:
                    if ge in m[5]:
#                         print(min_count[t][1])
                        li.remove(min_count[t][1])
                        b=1
            if b==0:
                li.remove(min_count[0][1])
#         print(li)
        movie_t = movie_t.drop(li,axis=0)
    else:
#         print(li,min_count[0][1])
        li.remove(min_count[0][1])
        movie_t = movie_t.drop(li,axis=0)
#     else:
#         count=[]
#         c=0
#         genre={}
#         l = len(movie_new[movie_new['movieid']==i])
#         li = movie_new[movie_new['movieid']==i].index.tolist()
#         print(l,li)
#         for k in range(len(li)):
            
#             m = movie_new.iloc[li[k]]
#             c=0
#             min_count=[]
#     #         print(m)
#             if pd.isna(m[5]):
#                 pass
#             else:
#                 g = list(m[5].split(", "))
#     #             print(g)
#                 for f in range(len(g)):
#                     if g[f] not in genre.keys():
#                         genre[g[f]]=1
#                     else:
#                         genre[g[f]]+=1    
#             for j in range(len(movie_col)):
#                 if pd.isna(m[j]):
#                     c+=1
#             count.append(c)
#     #     print(list(float(count[s])) for s in range(len(count)) if count[s]==min(count))
#         for s in range(len(count)):
#             if count[s]==min(count):
#                 min_count.append((s,li[s]))
#     #     print(li)
#         v = list(genre.values())
#         k = list(genre.keys())
#         if len(v)>0:
#             ge = k[v.index(max(v))]
#     #             print(count[s])
#     #     print(count)        
#     #     print(min_count[0][1])
#             if len(min_count)==1:
#                 li.remove(min_count[0][1])
#             else:
#                 b=0
#                 for t in range(len(min_count)):
#                     m = movie_new.iloc[min_count[t][1]]
#     #                 print(m)
#                     if pd.isna(m[5]):
#                         pass
#                     else:
#                         if ge in m[5]:
#                             print(min_count[t][1])
#                             li.remove(min_count[t][1])
#                             b=1
#                 if b==0:
#                     li.remove(min_count[0][1])
#     #         print(li)
#             movie_new = movie_new.drop(li,axis=0)
#         else:
#             li.remove(min_count[0][1])
#             movie_new = movie_new.drop(li,axis=0)
# print(count)

# %%
len(list(movie_t['movieid'][movie_t['movieid'].duplicated()]))

# %%
movie_t

# %%
train

# %%
train_tr = pd.merge(train,movie_t,on='movieid',how='left')

# %%
train_tr

# %%
test

# %%
test_tr = pd.merge(test,movie_t,on='movieid',how='left')

# %%
test_tr

# %%
test_tr.head()

# %%
train_tr.info()

# %%
train_tr = train_tr.drop('reviewerName',axis=1)

# %%
test_tr = test_tr.drop('reviewerName',axis=1)

# %%
train_tr['sentiment'].value_counts()

# %%
train_tr['genre'][train_tr['sentiment']=="POSITIVE"].value_counts()[:15]

# %%
train_tr['director'].value_counts()

# %%
train_tr['genre'][train_tr['director']=="Louise Bodrick"].value_counts()[:10]

# %%
na = np.where(pd.isna(train_tr['genre']))   #[train_tr['sentiment']=='POSITIVE'].value_counts()

# %%
na[0]

# %%
len(na[0])

# %%
pd.isna(train_tr['genre'][3])

# %%
train_tr['sentiment'].iloc[na].value_counts()

# %%
train_tr['genre'] = np.where((train_tr["sentiment"] == "POSITIVE") & (pd.isna(train_tr['genre'])),'Drama',train_tr['genre'])

# %%
train_tr['genre'] = np.where((train_tr["sentiment"] == "NEGATIVE") & (pd.isna(train_tr['genre'])),'Action',train_tr['genre'])

# %%
train_tr.info()

# %%
test_tr.info()

# %%
from sklearn.impute import SimpleImputer,KNNImputer

# %%
num_im = SimpleImputer(strategy='median')
cat_im = SimpleImputer(strategy='most_frequent')
ex_im = KNNImputer()

# %%
train_tr['reviewText'][1]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
cat_im.fit_transform(np.array(test_tr['genre']).reshape(1,-1))

# %%
test_tr.info()

# %%
test_tr["director"].value_counts()

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Joseph Brooks") & (pd.isna(test_tr['genre'])),'Drama',test_tr['genre'])

# %%
test_tr.info()

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Billy Diaz") & (pd.isna(test_tr['genre'])),'Comedy, Drama, Crime',test_tr['genre'])

# %%
test_tr.info()

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Sheila Pereira") & (pd.isna(test_tr['genre'])),'Sci-fi, Horror, Mystery & thriller',test_tr['genre'])

# %%
test_tr.info()

# %%
test_tr['director'][pd.isna(test_tr['genre'])].value_counts()[:10]

# %%
train_tr['genre'][train_tr['director']=="Kristine Chatman"].value_counts()[:10]

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Augusta Daniel") & (pd.isna(test_tr['genre'])),'Drama',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Philip Contreras") & (pd.isna(test_tr['genre'])),'Action',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Linda Proudfoot") & (pd.isna(test_tr['genre'])),'Action',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Rodolfo Carter") & (pd.isna(test_tr['genre'])),'Action',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Louise Bodrick") & (pd.isna(test_tr['genre'])),'Drama',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Brenda Erwin") & (pd.isna(test_tr['genre'])),'Action',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Donald Page") & (pd.isna(test_tr['genre'])),'Drama',test_tr['genre'])

# %%
test_tr['genre'] = np.where((test_tr["director"] == "Kristine Chatman") & (pd.isna(test_tr['genre'])),'Drama',test_tr['genre'])

# %%
test_tr['genre'] = np.where(pd.isna(test_tr['genre']),'Drama',test_tr['genre'])

# %%
test_tr.info()

# %%
train_tr.info()

# %%
test_tr1 = test_tr.drop(['rating','ratingContents'],axis=1)
train_tr1 = train_tr.drop(['rating','ratingContents'],axis=1)

# %%
train_tr1.info()

# %%
test_tr1.info()

# %%
train_tr1['audienceScore'] = ex_im.fit_transform(train_tr1[['audienceScore']])

# %%
test_tr1['audienceScore'] = ex_im.transform(test_tr1[['audienceScore']])

# %%
train_tr1['reviewText'] = cat_im.fit_transform(train_tr1[['reviewText']])
test_tr1['reviewText'] = cat_im.transform(test_tr1[['reviewText']])

# %%
# len(train_tr1['title'].unique())

# %%
test_tr2 = test_tr1.drop(["title",'director'],axis=1)
train_tr2 = train_tr1.drop(["title",'director'],axis=1)

# %%
test_tr2

# %%
train_tr2

# %%
train_tr2['isFrequentReviewer'] = np.where(train_tr2['isFrequentReviewer']==False,0,1)
test_tr2['isTopCritic'] = np.where(test_tr2['isTopCritic']==False,0,1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()
vec = TfidfVectorizer()
c_vec = CountVectorizer()

# %%
train_tr2['audienceScore'] = scale.fit_transform(train_tr2[['audienceScore']])

# %%
test_tr2['audienceScore'] = scale.transform(test_tr2[['audienceScore']])

# %%
ch = list(i[0] for i in np.array(train_tr2[['genre']]))

# %%
ch

# %%
ch1 = c_vec.fit_transform(ch)

# %%
y = train_tr1['sentiment']

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)

# %%
# train_

# %%
# co = [i for i in range(41)]
ch1

# %%
# train_vec = pd.DataFrame(ch1,train_tr2['isFrequentReviewer'],columns=co)

# %%
# train_tr2['genre'] = c_vec.fit_transform(train_tr2[['genre']])

# %%
train_tr2

# %%
y_train1 = train_tr2['sentiment']

# %%
y_train2 = np.where(y_train1=='POSITIVE',1,0)

# %%
x_tr = train_tr2.drop('sentiment',axis=1)

# %%
test_tr2

# %%
x_tr

# %%
x_tr.rename(columns = {'isFrequentReviewer':'isTopCritic'}, inplace = True)

# %%
x_tr

# %%
data = pd.concat([x_tr,test_tr2],axis=0)

# %%
data

# %%
# data['f'] = data['isTopCritic'],",",data['reviewText'],",",data['genre']
data['f'] = data.apply(lambda x: str(x['isTopCritic'])+","+str(x['reviewText'])+","+str(x['genre']), axis=1)

# %%
data

# %%
x_train_all = data['f']

# %%
x_train_untr = x_train_all[:162758]

# %%
x_train_untr

# %%
x_test_untr = x_train_all[162758:]

# %%
x_test_untr

# %%
x_all_untr = pd.concat([x_train_untr,x_test_untr],axis=0)

# %%
x_all_untr

# %%
# for i in range(len(x_test_untr)):
#     x_test_untr[i] = x_test_untr[i].replace(","," ")

# %%
# x_test_untr

# %%
# x_train_all[0]

# %%
# for i in range(len(x_train_all)):
#     x_train_all[i] = x_train_all[i].replace(","," ")
# len(x_train_all)

# %%
x_train_vec_all = c_vec.fit_transform(x_all_untr)

# %%
x_train_vec_all

# %%
x_train_all_tr = x_train_vec_all[:162758]

# %%
x_test_all_tr = x_train_vec_all[162758:]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,VotingClassifier,StackingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(x_train_all_tr,y_train2,test_size=0.25,random_state=42)

# %%
y_train

# %%
from sklearn.metrics import f1_score

# %%
# model1 = RandomForestClassifier()
# model1.fit(x_train,y_train)
# y_model1 = model1.predict(x_test)
# score1 = f1_score(y_test, y_model1)
# score1

# %%
# model2 = DecisionTreeClassifier()
# model2.fit(x_train,y_train)

# %%
# y_model2 = model2.predict(x_test)

# %%
# score2 = f1_score(y_test, y_model2)
# score2

# %%
from sklearn.linear_model import Perceptron,SGDClassifier

# %%
# model3 = Perceptron()
# model3.fit(x_train,y_train)
# y_model3 = model3.predict(x_test)
# score3 = f1_score(y_test, y_model3)
# score3

# %%
model4 = SGDClassifier()
model4.fit(x_train,y_train)
y_model4 = model4.predict(x_test)
score4 = f1_score(y_test, y_model4)
score4

# %%
# model5 = AdaBoostClassifier()
# model5.fit(x_train,y_train)
# y_model5 = model5.predict(x_test)
# score5 = f1_score(y_test, y_model5)
# score5

# %%
# model6 = GradientBoostingClassifier()
# model6.fit(x_train,y_train)
# y_model6 = model6.predict(x_test)
# score6 = f1_score(y_test, y_model6)
# score6

# %%
from sklearn.svm import SVC

# %%
# model7 = SVC()
# model7.fit(x_train,y_train)
# y_model7 = model7.predict(x_test)
# score7 = f1_score(y_test, y_model7)
# score7

# %%
# from sklearn.neighbors import KNeighborsClassifier
# model8 = KNeighborsClassifier()
# model8.fit(x_train,y_train)
# y_model8 = model8.predict(x_test)
# score8 = f1_score(y_test, y_model8)
# score8

# %%
# import xgboost as xgb
# model9 = xgb.XGBClassifier()
# model9.fit(x_train,y_train)
# y_model9 = model9.predict(x_test)
# score9 = f1_score(y_test, y_model9)
# score9

# %%
# from sklearn.neural_network import MLPClassifier
# model10 = MLPClassifier()
# model10.fit(x_train,y_train)
# y_model10 = model10.predict(x_test)
# score10 = f1_score(y_test, y_model10)
# score10

# %%
print('hii')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model11 = LogisticRegression()
model11.fit(x_train,y_train)
y_model11 = model11.predict(x_test)
score11 = f1_score(y_test, y_model11)
score11

# %%
from catboost import CatBoostClassifier

# %%
cat_model = CatBoostClassifier(verbose=0)
cat_model.fit(x_train,y_train)

# %%
y_cat_model = cat_model.predict(x_test)
score_cat_model = f1_score(y_test, y_cat_model)
score_cat_model

# %%
#  x_train_lgbm = x_train.astype('float32')
#  x_test_lgbm = x_test.astype('float32')   
#  y_train_lgbm = y_train.astype('float32')
#  y_test_lgbm = y_test.astype('float32')

# %%
from lightgbm import LGBMClassifier

# %%
# model12 = LGBMClassifier()
# model12.fit(x_train_lgbm,y_train_lgbm)

# %%
# y_model12 = model12.predict(x_test_lgbm)
# score12 = f1_score(y_test_lgbm, y_model12)
# score12

# %%
model13=VotingClassifier(estimators=[('sgd',model4),('log',model11),('cat',cat_model)])

# %%
model13.fit(x_train_all_tr,y_train2)

# %%
y_model13 = model13.predict(x_test_all_tr)
# score13 = f1_score(y_test, y_model13)
# score13

# %%
# model14 = StackingClassifier(estimators=[('sgd',model4),('cat',cat_model),("mlp",model10)], final_estimator=LogisticRegression())

# %%
# model14.fit(x_train,y_train)

# %%
# y_model14 = model14.predict(x_test)
# score14 = f1_score(y_test, y_model14)
# score14

# %%
y_model13= np.where(y_model13==1,'POSITIVE','NEGATIVE')

# %%
submission = pd.DataFrame(columns=["id","sentiment"])
submission['id']=[i for i in range(len(y_model13))]
submission["sentiment"] = y_model13
submission.to_csv("/kaggle/working/submission.csv",index=False)

# %%
submission
